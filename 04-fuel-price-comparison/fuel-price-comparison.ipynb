# %%
import os
import csv
import requests
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot as plt
# %matplotlib inline
from pylab import rcParams
rcParams['figure.figsize'] = 19, 9

# %%
url = 'http://www.anp.gov.br/images/dadosabertos/precos/2019-04-gasolina-etanol.csv'
response = requests.get(url)
with open(os.path.join("data", "2019-04-gasolina-etanol.csv"), 'w') as f:
    f.write(response.content.decode('utf16'))

# %%
data = pd.read_csv("data/2019-04-gasolina-etanol.csv", sep="\t", encoding="utf-16")

# %%
data.head()
# Out:
#   Região - Sigla Estado - Sigla Município  \
# 0             CO             DF  BRASILIA
# 1             CO             DF  BRASILIA
# 2             CO             DF  BRASILIA
# 3             CO             DF  BRASILIA
# 4             CO             DF  BRASILIA
#
#                                        Revenda  Instalação - Código Produto  \
# 0                       AUTO POSTO LAZZAT LTDA                 7770  ETANOL
# 1        CALLTECH COMBUSTIVEIS E SERVICOS LTDA               153708  ETANOL
# 2       CASCOL COMBUSTIVEIS PARA VEICULOS LTDA               192986  ETANOL
# 3      DISTRIBUIDORA BRASILIA DE VEICULOS S.A.                 8085  ETANOL
# 4  GOES COMBUSTIVEIS, LUBRIFICANTES E GLP LTDA                 7885  ETANOL
#
#   Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 0     01/04/2019          3,259          3,0092        R$ / litro
# 1     01/04/2019          3,399             NaN        R$ / litro
# 2     01/04/2019          3,199             NaN        R$ / litro
# 3     01/04/2019          3,289             NaN        R$ / litro
# 4     01/04/2019          3,399          3,0803        R$ / litro
#
#                        Bandeira
# 0                        BRANCA
# 1                      IPIRANGA
# 2  PETROBRAS DISTRIBUIDORA S.A.
# 3                        RAIZEN
# 4  PETROBRAS DISTRIBUIDORA S.A.

# %%
data = data.dropna()

# %%
data["Valor de Compra"] = data["Valor de Compra"].str.replace(",", ".")
data["Valor de Venda"] = data["Valor de Venda"].str.replace(",", ".")

# %%
data.dtypes
# Out:
# Região - Sigla         object
# Estado - Sigla         object
# Município              object
# Revenda                object
# Instalação - Código     int64
# Produto                object
# Data da Coleta         object
# Valor de Venda         object
# Valor de Compra        object
# Unidade de Medida      object
# Bandeira               object
# dtype: object

# %%
data["Região - Sigla"] = data["Região - Sigla"].astype('category')
data["Estado - Sigla"] = data["Estado - Sigla"].astype('category')
data["Município"] = data["Município"].astype('category')
data["Revenda"] = data["Revenda"].astype('category')
data["Instalação - Código"] = data["Instalação - Código"].astype('category')
data["Produto"] = data["Produto"].astype('category')
data["Valor de Venda"] = data["Valor de Venda"].astype(float)
data["Valor de Compra"] = data["Valor de Compra"].astype(float)
data["Valor de Venda"] = data["Valor de Venda"].astype(float)
data["Unidade de Medida"] = data["Unidade de Medida"].astype('category')
data["Bandeira"] = data["Bandeira"].astype('category')

# %%
data["Data da Coleta"] = pd.to_datetime(data["Data da Coleta"], format='%d/%m/%Y')

# %%
# fig, ax = plt.subplots(figsize=(15,7))
pd.DataFrame(data.groupby(['Região - Sigla', 'Produto'])[['Valor de Venda', 'Produto']]
             .mean())
# Out:
#                          Valor de Venda
# Região - Sigla Produto
# CO             ETANOL          3.056469
#                GASOLINA        4.408860
# N              ETANOL          3.698063
#                GASOLINA        4.535871
# NE             ETANOL          3.506053
#                GASOLINA        4.532407
# S              ETANOL          3.427119
#                GASOLINA        4.468537
# SE             ETANOL          3.124076
#                GASOLINA        4.430554

# %%
cps = data[data.Município.isin(['CAMPINAS'])]

# %%
cps.head()
# Out:
#       Região - Sigla Estado - Sigla Município  \
# 17863             SE             SP  CAMPINAS
# 17864             SE             SP  CAMPINAS
# 17865             SE             SP  CAMPINAS
# 17866             SE             SP  CAMPINAS
# 17867             SE             SP  CAMPINAS
#
#                                  Revenda Instalação - Código Produto  \
# 17863               AUTO POSTO 100 LTDA.              169492  ETANOL
# 17864          AUTO POSTO APPALOOSA LTDA               55918  ETANOL
# 17865  AUTO POSTO CAMPO DOS AMARAIS LTDA               55928  ETANOL
# 17866    AUTO POSTO CB PAR CAMPINAS LTDA              216642  ETANOL
# 17867             AUTO POSTO ESKEMA LTDA               55978  ETANOL
#
#       Data da Coleta  Valor de Venda  Valor de Compra Unidade de Medida  \
# 17863     2019-04-01           2.787           2.3051        R$ / litro
# 17864     2019-04-01           2.999           2.3742        R$ / litro
# 17865     2019-04-01           2.799           2.3740        R$ / litro
# 17866     2019-04-01           2.599           2.3600        R$ / litro
# 17867     2019-04-01           2.799           2.3435        R$ / litro
#
#                            Bandeira
# 17863  PETROBRAS DISTRIBUIDORA S.A.
# 17864                      IPIRANGA
# 17865                      IPIRANGA
# 17866                        BRANCA
# 17867                      IPIRANGA

# %%
cps.groupby(['Produto']).boxplot(column=['Valor de Compra', 'Valor de Venda'])
# Out:
# ETANOL           AxesSubplot(0.1,0.15;0.363636x0.75)
# GASOLINA    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
# cps.boxplot(x = 'Data da Coleta', y='Valor de Venda')
pd.DataFrame(cps.groupby(['Data da Coleta', 'Bandeira', 'Produto'])['Valor de Venda'].mean()).groupby(['Produto']).boxplot(by='Bandeira', rot=90)
# Out:
# ETANOL           AxesSubplot(0.1,0.15;0.363636x0.75)
# GASOLINA    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
fig, ax = plt.subplots()
#pd.DataFrame(cps.groupby(['Data da Coleta', 'Bandeira'])['Valor de Venda'].mean()).unstack().plot(ax=ax)
pd.DataFrame(cps.groupby(['Data da Coleta', 'Bandeira', 'Produto'])['Valor de Venda'].mean()).groupby(['Bandeira', 'Produto']).plot(ax=ax)
# Out:
# Bandeira     Produto
# AIR BP       ETANOL      AxesSubplot(0.125,0.125;0.775x0.755)
#              GASOLINA    AxesSubplot(0.125,0.125;0.775x0.755)
# ALESAT       ETANOL      AxesSubplot(0.125,0.125;0.775x0.755)
#              GASOLINA    AxesSubplot(0.125,0.125;0.775x0.755)
# AMERICANOIL  ETANOL      AxesSubplot(0.125,0.125;0.775x0.755)
#                                          ...
# UNI          GASOLINA    AxesSubplot(0.125,0.125;0.775x0.755)
# WATT         ETANOL      AxesSubplot(0.125,0.125;0.775x0.755)
#              GASOLINA    AxesSubplot(0.125,0.125;0.775x0.755)
# ZEMA         ETANOL      AxesSubplot(0.125,0.125;0.775x0.755)
#              GASOLINA    AxesSubplot(0.125,0.125;0.775x0.755)
# Length: 96, dtype: object

# %%
#fig, ax = plt.subplots(figsize=(15,7))
# cps['Diff'] = cps['Valor de Venda'] - 'Valor de Compra'
pd.DataFrame(cps.groupby(['Data da Coleta', 'Produto'])[['Valor de Venda', 'Valor de Compra']].mean()).groupby(['Produto']).plot()
# Out:
# Produto
# ETANOL      AxesSubplot(0.125,0.125;0.775x0.755)
# GASOLINA    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
